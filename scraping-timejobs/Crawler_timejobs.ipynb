# %%
from bs4 import BeautifulSoup
import requests
import time
from datetime import datetime

def find_jobs():
    html_text = requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=")
    soup      = BeautifulSoup(html_text.text,'lxml')
    jobs      = soup.find_all('li',  class_ = "clearfix job-bx wht-shd-bx")

    for index,job in enumerate(jobs):
        file_name = "post_" + str(index) + "_.txt"
        published_date = job.find('span', class_ = "sim-posted")

        if "few" in published_date.text:
            more_info      = job.header.h2.a
            company_name   = job.find('h3',   class_ = "joblist-comp-name")
            skills         = job.find('span', class_ = "srp-skills")

            if unfamiliar_skill not in skills:
                with open(file_name,"w") as f:
                    
                    print(f"Company Name    : {company_name.text.strip()}")
                    f.write(f"Company Name  : {company_name.text.strip()} \n")
                    print(f"Required Skill: :{skills.text.strip()}")
                    f.write(f"Required Skill: {skills.text.strip()} \n")
                    print(f"More Info       : {more_info['href']}")
                    f.write(f"More Info     : {more_info['href']} \n")
                
                print("File saved")

# Take a html text from url
print("Time Period")
time_wait = int(input(">"))

print("Put some skill you are not familiar with")
unfamiliar_skill = input(">")
print("Filtering out {unfamiliar_skill}")

if __name__ == "__main__":
    while True:
        now = datetime.now()
        print(now)
        find_jobs()
        time.sleep(time_wait)
# Out:
# Time Period
# >5
# Put some skill you are not familiar with
# >java
# Filtering out {unfamiliar_skill}
# 2021-06-17 09:43:29.309302
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:43:40.006331
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:43:47.457193
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:43:54.981700
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:02.722713
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:10.049677
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:26.793425
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:34.072274
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:41.275138
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:48.854429
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:44:56.510020
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:45:04.030458
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:45:11.702630
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:45:19.027418
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:45:26.767917
# Company Name    : Surya Informatics Solutions Pvt. Ltd.
# Required Skill: :python  ,  web technologies  ,  linux  ,  mobile  ,  mysql  ,  angularjs  ,  javascript
# More Info       : https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Pure Tech Codex Private Limited
# Required Skill: :rest  ,  python  ,  database  ,  django  ,  debugging  ,  mongodb
# More Info       : https://www.timesjobs.com/job-detail/python-pure-tech-codex-private-limited-pune-2-to-3-yrs-jobid-OHwfF0d6EhNzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : GEMINI SOFTWARE SOLUTIONS
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-software-solutions-gurgaon-4-to-7-yrs-jobid-jsOuZLK8chlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Gemini Solutions
# Required Skill: :python  ,  mobile  ,  svn  ,  nosql  ,  python scripting  ,  git  ,  api  ,  sql database
# More Info       : https://www.timesjobs.com/job-detail/qa-python-python-sdet-gemini-solutions-gurgaon-4-to-7-yrs-jobid-eGMLzwOk2QlzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : LAKSH HUMAN RESOURCE
# Required Skill: :rest  ,  python  ,  django  ,  git
# More Info       : https://www.timesjobs.com/job-detail/python-developer-laksh-human-resource-mumbai-1-to-3-yrs-jobid-Bo79FYBR7__SLASH__5zpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : Angel and Genie
# Required Skill: :python  ,  security  ,  debugging  ,  opencv
# More Info       : https://www.timesjobs.com/job-detail/python-developer-angel-and-genie-noida-greater-noida-3-to-6-yrs-jobid-Plg0JDJmGwFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : SATRA Infrastructure Management
# Required Skill: :algorithms  ,  python  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-satra-infrastructure-management-hyderabad-secunderabad-5-to-8-yrs-jobid-NN4FiC2z3rhzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : WHITE FORCE
# Required Skill: :python  ,  mobile  ,  debugging
# More Info       : https://www.timesjobs.com/job-detail/python-developer-white-force-chennai-2-to-4-yrs-jobid-hLnxtF76yRtzpSvf__PLUS__uAgZw==&source=srp
# File saved
# Company Name    : FresherMart
# Required Skill: :python  ,  django  ,   Django Framework
# More Info       : https://www.timesjobs.com/job-detail/python-developer-freshermart-navi-mumbai-mumbai-0-to-1-yrs-jobid-PUYMPEa4NaFzpSvf__PLUS__uAgZw==&source=srp
# File saved
# 2021-06-17 09:45:34.031703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d6e01dab1365> in <module>
#      42         now = datetime.now()
#      43         print(now)
# ---> 44         find_jobs()
#      45         time.sleep(time_wait)
#
# <ipython-input-1-d6e01dab1365> in find_jobs()
#       5
#       6 def find_jobs():
# ----> 7     html_text = requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=")
#       8     soup      = BeautifulSoup(html_text.text,'lxml')
#       9     jobs      = soup.find_all('li',  class_ = "clearfix job-bx wht-shd-bx")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
